# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.metrics import r2_score
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

# %%
X = 6 * np.random.rand(200, 1) - 3
y = 0.8 * X ** 2 + 0.9 * X + 2 + np.random.rand(200, 1)

# %%
plt.scatter(X, y)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

print("R2 Score", r2_score(y_test, y_pred))
# Out:
# R2 Score 0.12663776362549495

# %%
plt.plot(X_train, lr.predict(X_train), color='red')
plt.scatter(X, y, color='b', marker='.')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
poly = PolynomialFeatures(degree=2)

X_train_trans = poly.fit_transform(X_train)
X_test_trans = poly.transform(X_test)

# %%
print(X_train[0], X_train_trans[0])
print(X_test[0], X_test_trans[0])
# Out:
# [2.50925889] [1.         2.50925889 6.29638019]
# [2.65143818] [1.         2.65143818 7.03012445]

# %%
lr = LinearRegression()
lr.fit(X_train_trans, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test_trans)
print("R2 Score", r2_score(y_test, y_pred))
# Out:
# R2 Score 0.986031499016077

# %%
print(lr.intercept_)
# Out:
# [2.47830989]

# %%
X_new = np.linspace(-3, 3, 200).reshape(200, 1)
X_new_poly = poly.transform(X_new)
y_new = lr.predict(X_new_poly)

# %%
plt.plot(X_new, y_new, "r-", linewidth=2, label='Predicitons')
plt.plot(X_train, y_train, "b.", label='Training points')
plt.plot(X_test, y_test, 'g.', label='Trainging points')
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()
